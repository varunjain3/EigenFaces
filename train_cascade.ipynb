# %% [markdown]
# <a href="https://colab.research.google.com/github/varunjain3/EigenFaces/blob/master/train_cascade.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline
import cv2 as cv
import os
import PIL
import matplotlib.pyplot as plt
import numpy as np

# %%
# !git clone https://github.com/varunjain3/EigenFaces.git
# Out:
# Cloning into 'EigenFaces'...
# remote: Enumerating objects: 4432, done.
# remote: Total 4432 (delta 0), reused 0 (delta 0), pack-reused 4432
# Receiving objects: 100% (4432/4432), 102.62 MiB | 16.85 MiB/s, done.
# Resolving deltas: 100% (5/5), done.

# %%
# %cd EigenFaces/
# Out:
# [Errno 2] No such file or directory: 'EigenFaces/'
# /content/EigenFaces

# %%
DATASET = os.path.join(os.getcwd(),"YALE") 
DATA_DIR = os.path.join(os.getcwd(),"data") 
print("Dataset Dir is ",DATASET)
print("Data dir ",DATA_DIR)
# Out:
# Dataset Dir is  /content/EigenFaces/YALE
# Data dir  /content/EigenFaces/data

# %%
def read_im(path):
    image = PIL.Image.open(path)
    return np.array(image)

def show_im(image):
    plt.imshow(image,cmap="gray")
    plt.show()

def find_faces(gray):
  faces = face_cascade.detectMultiScale(gray, 1.3, 3)
  return faces

# %%
# For preparing pos images 
count = 0

for dirpath, dirnames, filenames in os.walk(FACE_DIR):
    for file in filenames:
        i = count // 11 + 1
        j = count % 11 + 1
        count+= 1

        # print(file)
        im = PIL.Image.open(os.path.join(dirpath,file)) 
        im_flip = im.transpose(PIL.Image.FLIP_LEFT_RIGHT)
        # print(i,j)
        new_file = "data/pos/" + str(i).zfill(2) + str(j).zfill(2) + '.jpg'
        flip_file = "data/pos/" + str(i).zfill(2) + str(j).zfill(2) + '_flip.jpg'
        print(new_file,flip_file)
        im.save(new_file)
        im_flip.save(flip_file)

# %%
POS_DIR = os.path.join(DATA_DIR,"pos")
print(POS_DIR)

# %%
im = np.array(im)

# %%
face_cascade = cv.CascadeClassifier('haarcascade_frontalface_default.xml')

# %%
for dirpath, dirnames, filenames in os.walk(POS_DIR):
    for file in filenames:
        img = read_im(os.path.join(dirpath,file))
        faces = find_faces(img)
        # print(faces)
        line = "pos" + "/" + file + " 1 {} {} {} {}\n".format(faces[0][0],faces[0][1],faces[0][2],faces[0][3])
        with open(os.path.join(POS_DIR,"info.dat"),'a') as f:
            f.write(line)
        # print(line)

# %%
NEG_DATASET = os.path.join(DATA_DIR,'gitneg')
max = 600
count = 0

NEG_DIR = os.path.join(DATA_DIR,'neg')

for dirpath, dirnames, filenames in os.walk(NEG_DATASET):
    for file in filenames:
        count += 1
        if count > max:
            break
        img = read_im(os.path.join(dirpath,file))
        img = cv.resize(img,im.T.shape,cv.INTER_AREA)
        line = "neg/{}\n".format(file)
        cv.imwrite(os.path.join(NEG_DIR,file),img)
        print(line)  
        with open(os.path.join(NEG_DIR,"bg.txt"),'a') as f:
            f.write(line)
# Out:
# neg/neg-0002.jpg
#
# neg/neg-0003.jpg
#
# neg/neg-0004.jpg
#
# neg/neg-0005.jpg
#
# neg/neg-0006.jpg
#
# neg/neg-0007.jpg
#
# neg/neg-0009.jpg
#
# neg/neg-0010.jpg
#
# neg/neg-0011.jpg
#
# neg/neg-0012.jpg
#
# neg/neg-0013.jpg
#
# neg/neg-0015.jpg
#
# neg/neg-0016.jpg
#
# neg/neg-0019.jpg
#
# neg/neg-0020.jpg
#
# neg/neg-0022.jpg
#
# neg/neg-0023.jpg
#
# neg/neg-0024.jpg
#
# neg/neg-0025.jpg
#
# neg/neg-0026.jpg
#
# neg/neg-0027.jpg
#
# neg/neg-0028.jpg
#
# neg/neg-0029.jpg
#
# neg/neg-0030.jpg
#
# neg/neg-0031.jpg
#
# neg/neg-0034.jpg
#
# neg/neg-0035.jpg
#
# neg/neg-0036.jpg
#
# neg/neg-0037.jpg
#
# neg/neg-0038.jpg
#
# neg/neg-0039.jpg
#
# neg/neg-0040.jpg
#
# neg/neg-0041.jpg
#
# neg/neg-0042.jpg
#
# neg/neg-0044.jpg
#
# neg/neg-0045.jpg
#
# neg/neg-0046.jpg
#
# neg/neg-0047.jpg
#
# neg/neg-0048.jpg
#
# neg/neg-0049.jpg
#
# neg/neg-0050.jpg
#
# neg/neg-0051.jpg
#
# neg/neg-0052.jpg
#
# neg/neg-0053.jpg
#
# neg/neg-0054.jpg
#
# neg/neg-0055.jpg
#
# neg/neg-0056.jpg
#
# ...

# %%
im.shape
# Out:
# (243, 320)

# %%
# !git clone https://github.com/opencv/opencv.git
# Out:
# Cloning into 'opencv'...
# remote: Enumerating objects: 40, done.
# remote: Counting objects: 100% (40/40), done.
# remote: Compressing objects: 100% (35/35), done.
# remote: Total 280057 (delta 8), reused 16 (delta 5), pack-reused 280017
# Receiving objects: 100% (280057/280057), 473.13 MiB | 16.53 MiB/s, done.
# Resolving deltas: 100% (195609/195609), done.
# Checking out files: 100% (6592/6592), done.

# %%
# !sudo apt-get install build-essential
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# build-essential is already the newest version (12.4ubuntu1).
# 0 upgraded, 0 newly installed, 0 to remove and 22 not upgraded.

# %%
# !sudo apt-get install cmake git libgtk2.0-dev pkg-config libavcodec-dev libavformat-dev libswscale-dev
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# pkg-config is already the newest version (0.29.1-0ubuntu2).
# cmake is already the newest version (3.10.2-1ubuntu2.18.04.1).
# git is already the newest version (1:2.17.1-1ubuntu0.7).
# libavcodec-dev is already the newest version (7:3.4.8-0ubuntu0.2).
# libavcodec-dev set to manually installed.
# libavformat-dev is already the newest version (7:3.4.8-0ubuntu0.2).
# libavformat-dev set to manually installed.
# libswscale-dev is already the newest version (7:3.4.8-0ubuntu0.2).
# libswscale-dev set to manually installed.
# The following additional packages will be installed:
#   autoconf automake autopoint autotools-dev debhelper dh-autoreconf
#   dh-strip-nondeterminism file gettext gettext-base gir1.2-atk-1.0
#   gir1.2-freedesktop gir1.2-gdkpixbuf-2.0 gir1.2-gtk-2.0 gir1.2-pango-1.0
#   intltool-debian libarchive-cpio-perl libarchive-zip-perl libatk1.0-dev
# ...

# %%
# !sudo apt-get install python-dev python-numpy libtbb2 libtbb-dev libjpeg-dev libpng-dev libtiff-dev libjasper-dev libdc1394-22-dev
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# E: Unable to locate package libjasper-dev

# %%
# !sudo apt-get install libopencv-dev
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libopencv-dev is already the newest version (3.2.0+dfsg-4ubuntu0.1).
# 0 upgraded, 0 newly installed, 0 to remove and 22 not upgraded.

# %%
# !ls
# Out:
# data	     faces				  opencv       YALE
# eigen.ipynb  haarcascade_frontalface_default.xml  train.ipynb

# %%
# %cd data
# !ls
# Out:
# [Errno 2] No such file or directory: 'data'
# /content/EigenFaces/data
# bg.txt	gitneg	info.dat  neg  pos

# %%
# !opencv_createsamples -info info.dat -num 550 -w 100 -h 50 -vec info.vec
# !ls
# Out:
# Info file name: info.dat
# Img file name: (NULL)
# Vec file name: info.vec
# BG  file name: (NULL)
# Num: 550
# BG color: 0
# BG threshold: 80
# Invert: FALSE
# Max intensity deviation: 40
# Max x angle: 1.1
# Max y angle: 1.1
# Max z angle: 0.5
# Show samples: FALSE
# Width: 100
# Height: 50
# Max Scale: -1
# Create training samples from images collection...
# info.dat(331) : parse errorDone. Created 330 samples
# bg.txt	gitneg	info.dat  info.vec  neg  pos

# %%
# !opencv_createsamples -vec info.vec -w 100 -h 50
# Out:
# Info file name: (NULL)
# Img file name: (NULL)
# Vec file name: info.vec
# BG  file name: (NULL)
# Num: 1000
# BG color: 0
# BG threshold: 80
# Invert: FALSE
# Max intensity deviation: 40
# Max x angle: 1.1
# Max y angle: 1.1
# Max z angle: 0.5
# Show samples: FALSE
# Width: 100
# Height: 50
# Max Scale: -1
# View samples from vec file (press ESC to exit)...
# Done

# %%
# !opencv_traincascade -data pos -vec info.vec -bg bg.txt -numStages 20 -minHitRate 0.999 -maxFalseAlarmRate 0.5 -numPos 250 -numNeg 550 -w 100 -h 50 -mode ALL -precalcValBufSize 1024 -precalcIdxBufSize 1024 -featureType LBP
# Out:
# PARAMETERS:
# cascadeDirName: pos
# vecFileName: info.vec
# bgFileName: bg.txt
# numPos: 250
# numNeg: 550
# numStages: 20
# precalcValBufSize[Mb] : 1024
# precalcIdxBufSize[Mb] : 1024
# acceptanceRatioBreakValue : -1
# stageType: BOOST
# featureType: LBP
# sampleWidth: 100
# sampleHeight: 50
# boostType: GAB
# minHitRate: 0.999
# maxFalseAlarmRate: 0.5
# weightTrimRate: 0.95
# maxDepth: 1
# maxWeakCount: 100
# Number of unique features given windowSize [100,50] : 673200
#
# ===== TRAINING 0-stage =====
# <BEGIN
# POS count : consumed   250 : 250
# NEG count : acceptanceRatio    550 : 1
# tcmalloc: large alloc 1073741824 bytes == 0x562fa52c4000 @  0x7f918291d1e7 0x7f9181b17382 0x7f9181c1621b 0x562f9758e608 0x562f9758ed42 0x562f9758ee1a 0x562f975981a9 0x562f97584fff 0x7f9180ddab97 0x562f97585c1a
# Precalculation time: 17
# +----+---------+---------+
# |  N |    HR   |    FA   |
# +----+---------+---------+
# |   1|        1|        1|
# +----+---------+---------+
# ...
